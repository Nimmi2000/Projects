# %%
# Importing packages
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# %%
# Initializing parameters

jobs = 4 # Number of jobs
machines = 6 # Number of machines
processing_time = [6,7,17,9,20,13]
v = 2 # Number of agvs
travel_time = [[0,3,4,5,6,7],[3,0,1,2,3,4],[4,1,0,1,2,3],[5,2,1,0,1,2],[6,3,2,1,0,1],[7,4,3,2,1,0]]
operations = [(i, j) for i in range(1,jobs+1) for j in range(1, machines + 1)]  # Example operations
l = 100000

# %%
# Initializing a model
model = gp.Model()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-01

# %%
# Decision variables
C_max = model.addVar( vtype = GRB.CONTINUOUS, name = 'C_max')
start_time_operation = model.addVars(range(1, jobs+1) , range( 1 , machines+1) , vtype = GRB.CONTINUOUS, lb=0, name = 'start_time_operation')
start_time_transportation = model.addVars(range(1 , jobs+1) , range( 1 , machines+1) , vtype = GRB.CONTINUOUS, lb=0, name = 'start_time_transportation') #Transportation for Job i and operatation j
y = model.addVars(operations, operations, vtype=GRB.BINARY, name="For operation precedence")
z = model.addVars(operations, operations, vtype=GRB.BINARY, name="For transportation precedence")

for i in range(1,jobs+1) :
    for j in range(1, machines+1) :
        for r in range(1, v+1) :
            x = model.addVars(range(1, jobs+1) , range( 1 , machines+1), range(1, v+1), vtype=GRB.BINARY, name="transportation by agv for job i and operation j binary variable")

# %%
#Adding constraints

#Constraint 1.1
for (i,j) in operations:
    if j<machines :
        model.addConstr(start_time_operation[i,j+1] >= start_time_operation[i,j] + processing_time[j] , name = f"ensuring sequence from {i}_{j}")

#Constraint 1.2 & 1.3
for (i,j) in operations:
    for (i_prime,j_prime) in operations:
        if (i,j) != (i_prime,j_prime):
            model.addConstr(start_time_operation[i,j] + l * y[i,j,i_prime,j_prime] >= start_time_operation[i_prime,j_prime] + processing_time[j_prime-1],name = f"seq{i_prime, j_prime} to seq{i, j}" )
            model.addConstr(start_time_operation[i_prime,j_prime] + l * (1 - y[i,j,i_prime,j_prime]) >= start_time_operation[i,j] + processing_time[j-1],name = f"seq{i, j} to seq{i_prime, j_prime}" ) 

#Constraint 1.4 & 1.5
for (i,j) in operations:
    if (j >=1) & (j < machines):
        model.addConstr(start_time_operation[i,j] + processing_time[j-1] <= start_time_transportation[i,j+1])
    if (j >=2) & (j < machines+1):
        model.addConstr(start_time_transportation[i,j] + travel_time[j-2][j-1] <= start_time_operation[i,j])

#Constraint 1.6
for (i,j) in operations:
    for (i_prime,j_prime) in operations:
        if (i,j) != (i_prime, j_prime):
            if (j >=2) & (j < machines+1) & (j_prime >=2) & (j_prime < machines+1):
                model.addConstr(start_time_transportation[i_prime,j_prime] + l* (1- z[i,j,i_prime,j_prime]) >= start_time_transportation[i,j] + travel_time[j-2][j-1] + travel_time[j-1][j_prime-2])

#Constraint 1.7 is divided as two to follow linearity (1.8 & 1.9)
for (i,j) in operations:
    for (i_prime,j_prime) in operations:
        for r in range(1, v+1):
            if (i,j) != (i_prime, j_prime):
                model.addConstr(z[i,j,i_prime,j_prime] + z[i_prime,j_prime, i, j] >= x[i,j,r] + x[i_prime,j_prime,r] - 1)
                model.addConstr(z[i,j,i_prime,j_prime] + z[i_prime,j_prime, i, j] <= x[i,j,r] - x[i_prime,j_prime,r] + 1)

#Constraint 1.10
for (i,j) in operations:
    model.addConstr(gp.quicksum(x[i, j, r] for r in range(1,v+1)) == 1, name=f"task_assign_exactly_one_agv_{i}_{j}_{r}")

#Constraint 1.11
for (i,j) in operations:
    model.addConstr(start_time_operation[i,j] + processing_time[j-1] <= C_max)

# %%
# Objective

model.setObjective(C_max, GRB.MINIMIZE)

# time limit of 3 minutes

model.setParam(GRB.Param.TimeLimit, 180)

# Optimization
model.optimize()
# Out:
# Set parameter TimeLimit to value 180
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-8300H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3800 rows, 3505 columns and 13500 nonzeros
# Model fingerprint: 0xfcf55803
# Variable types: 49 continuous, 3456 integer (3456 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+05]
# Presolve removed 1164 rows and 2442 columns
# Presolve time: 0.15s
# Presolved: 2636 rows, 1063 columns, 8572 nonzeros
# Variable types: 45 continuous, 1018 integer (1018 binary)
#
# Root relaxation: objective 9.800000e+01, 240 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   98.00000    0   48          -   98.00000      -     -    0s
# H    0     0                     291.0000000   98.00000  66.3%     -    0s
# H    0     0                     290.9999996   98.00000  66.3%     -    0s
#      0     0  129.60000    0  101  291.00000  129.60000  55.5%     -    0s
#      0     0  129.60000    0  100  291.00000  129.60000  55.5%     -    0s
#      0     0  129.60000    0  100  291.00000  129.60000  55.5%     -    0s
#      0     0  129.60000    0  100  291.00000  129.60000  55.5%     -    0s
#      0     0  129.60000    0  100  291.00000  129.60000  55.5%     -    0s
# H    0     0                     288.0000000  129.60000  55.0%     -    1s
#      0     0  129.60000    0  101  288.00000  129.60000  55.0%     -    1s
#      0     0  129.60000    0   96  288.00000  129.60000  55.0%     -    1s
#      0     0  129.60000    0   96  288.00000  129.60000  55.0%     -    1s
#      0     0  129.60000    0   96  288.00000  129.60000  55.0%     -    1s
#      0     0  129.60000    0   96  288.00000  129.60000  55.0%     -    1s
#      0     0  129.60000    0   96  288.00000  129.60000  55.0%     -    1s
#      0     0  129.60000    0   95  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   78  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   75  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   73  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   81  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   79  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   84  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   78  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   77  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   83  288.00000  129.60000  55.0%     -    2s
#      0     0  129.60000    0   79  288.00000  129.60000  55.0%     -    2s
#      0     2  129.60000    0   73  288.00000  129.60000  55.0%     -    2s
# H   68    68                     287.9999999  133.60000  53.6%  48.0    3s
# H   70    68                     287.9999995  133.60000  53.6%  47.2    3s
#   1235   951  175.00000   16  307  288.00000  139.56000  51.5%  21.0    5s
#   1390  1064  178.00000   28   55  288.00000  148.74424  48.4%  36.6   10s
#   4077  2133  207.01832   46  135  288.00000  148.74424  48.4%  33.1   15s
#   8308  4587  283.00000   58   73  288.00000  155.08261  46.2%  30.2   20s
#  12756  7052 infeasible   49       288.00000  158.00000  45.1%  29.2   25s
#  17031  9674  209.00000   33   82  288.00000  160.00000  44.4%  29.0   30s
#  23581 13336  281.00000   56   79  288.00000  162.77832  43.5%  27.3   35s
#  27791 15771  182.00000   42  131  288.00000  164.00000  43.1%  27.1   40s
#  29692 16575  264.00000   53  295  288.00000  164.00000  43.1%  26.9   50s
#  29716 16591  217.00000   41  237  288.00000  164.00000  43.1%  26.9   55s
#  29760 16620  260.81429   54  240  288.00000  164.00000  43.1%  26.8   60s
#  29780 16634  203.00000   53  167  288.00000  164.00000  43.1%  26.8   65s
#  29810 16654  232.00000   43  254  288.00000  164.00000  43.1%  26.8   70s
#  29825 16664  169.00000   30  210  288.00000  164.00000  43.1%  26.8   75s
#  30448 17015  271.00000   71   40  288.00000  164.00000  43.1%  28.6   80s
#  33415 17906  164.00000   46   87  288.00000  164.00000  43.1%  28.5   85s
#  36795 18791  182.00000   43   67  288.00000  164.00000  43.1%  28.4   90s
#  44296 19909  187.25714   51   57  288.00000  164.00000  43.1%  26.4   95s
#  50641 21582  219.50000   55   54  288.00000  165.00000  42.7%  25.1  100s
#  58903 23004  180.00000   54   28  288.00000  166.92857  42.0%  23.7  105s
#  66946 23425  197.00000   55   64  288.00000  168.00000  41.7%  22.7  110s
#  71313 24221  232.00000   52   53  288.00000  168.71431  41.4%  22.2  115s
#  80111 25799  245.00000   50   11  288.00000  170.00000  41.0%  21.3  120s
#  88059 29547     cutoff   71       288.00000  170.37348  40.8%  20.8  125s
#  99408 35966  204.00000   56   55  288.00000  171.53893  40.4%  20.1  130s
#  113008 42176 infeasible   49       288.00000  172.92857  40.0%  19.2  135s
#  121637 46570  250.00000   56   58  288.00000  173.30941  39.8%  18.7  140s
#  131043 51490  219.00000   44   53  288.00000  174.00000  39.6%  18.4  145s
#  145139 57982  249.00000   62   44  288.00000  175.00000  39.2%  17.8  150s
#  158463 64563     cutoff   68       288.00000  176.00000  38.9%  17.2  155s
#  171967 70887 infeasible   73       288.00000  176.94544  38.6%  16.8  160s
#  184427 77064 infeasible   66       288.00000  177.28987  38.4%  16.4  165s
#  197184 83553  193.00000   51   36  288.00000  178.00000  38.2%  16.1  170s
#  208513 88395  287.00000   54   41  288.00000  178.79188  37.9%  15.9  175s
#  220413 93592  179.00000   55   60  288.00000  179.00000  37.8%  15.6  180s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 35
#   Flow cover: 159
#   Inf proof: 11
#   Zero half: 17
#   RLT: 25
#   Relax-and-lift: 8
#
# Explored 220495 nodes (3453774 simplex iterations) in 180.04 seconds (91.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 288 288 288 ... 291
#
# Time limit reached
# Best objective 2.879999994827e+02, best bound 1.790000000000e+02, gap 37.8472%

# %%
if model.status == GRB.OPTIMAL or model.status == GRB.TIME_LIMIT:
    print(f"Minimized Makespan: {model.objVal}")

    # For getting all decision variables
    for decisionvariable in model.getVars():
        print(f"{decisionvariable.VarName} = {decisionvariable.X}")
# Out:
# Minimized Makespan: 287.99999948272784
# C_max = 287.99999948272784
# start_time_operation[1,1] = 17.999999949941405
# start_time_operation[1,2] = 30.999999949941415
# start_time_operation[1,3] = 102.99999994994143
# start_time_operation[1,4] = 137.99999994994147
# start_time_operation[1,5] = 215.99999997139352
# start_time_operation[1,6] = 274.99999948272784
# start_time_operation[2,1] = -4.672526393403283e-08
# start_time_operation[2,2] = 37.999999949941426
# start_time_operation[2,3] = 85.99999994994143
# start_time_operation[2,4] = 128.9999999499414
# start_time_operation[2,5] = 175.99999997139355
# start_time_operation[2,6] = 261.99999948272784
# start_time_operation[3,1] = 5.999999949941403
# start_time_operation[3,2] = 44.99999994994142
# start_time_operation[3,3] = 68.99999994994143
# start_time_operation[3,4] = 146.99999994994144
# start_time_operation[3,5] = 195.99999997139352
# start_time_operation[3,6] = 235.99999997139352
# start_time_operation[4,1] = 11.999999949941405
# start_time_operation[4,2] = 23.999999949941405
# start_time_operation[4,3] = 51.99999994994142
# start_time_operation[4,4] = 119.99999994994141
# start_time_operation[4,5] = 155.99999994994144
# start_time_operation[4,6] = 248.99999948272784
# start_time_transportation[1,1] = 0.0
# start_time_transportation[1,2] = 27.999999949941415
# start_time_transportation[1,3] = 85.0
# start_time_transportation[1,4] = 136.99999994994147
# start_time_transportation[1,5] = 157.99999994994144
# start_time_transportation[1,6] = 235.99999948272784
# start_time_transportation[2,1] = 0.0
# start_time_transportation[2,2] = 14.999999949941405
# start_time_transportation[2,3] = 68.0
# start_time_transportation[2,4] = 102.99999994994143
# start_time_transportation[2,5] = 149.0
# start_time_transportation[2,6] = 199.0
# start_time_transportation[3,1] = 0.0
# start_time_transportation[3,2] = 41.99999994994142
# start_time_transportation[3,3] = 51.99999948272785
# start_time_transportation[3,4] = 101.0
# start_time_transportation[3,5] = 155.99999994994144
# start_time_transportation[3,6] = 234.99999997139352
# start_time_transportation[4,1] = 0.0
# start_time_transportation[4,2] = 20.999999949941405
# start_time_transportation[4,3] = 34.0
# start_time_transportation[4,4] = 100.99999994994143
# start_time_transportation[4,5] = 129.0
# start_time_transportation[4,6] = 184.0
# For operation precedence[1,1,1,1] = 0.0
# For operation precedence[1,1,1,2] = 1.0
# For operation precedence[1,1,1,3] = 1.0
# For operation precedence[1,1,1,4] = 1.0
# For operation precedence[1,1,1,5] = 1.0
# For operation precedence[1,1,1,6] = 1.0
# For operation precedence[1,1,2,1] = 0.0
# For operation precedence[1,1,2,2] = 1.0
# For operation precedence[1,1,2,3] = 1.0
# For operation precedence[1,1,2,4] = 1.0
# For operation precedence[1,1,2,5] = 1.0
# For operation precedence[1,1,2,6] = 1.0
# For operation precedence[1,1,3,1] = 0.0
# For operation precedence[1,1,3,2] = 1.0
# For operation precedence[1,1,3,3] = 1.0
# For operation precedence[1,1,3,4] = 1.0
# For operation precedence[1,1,3,5] = 1.0
# For operation precedence[1,1,3,6] = 1.0
# For operation precedence[1,1,4,1] = 0.0
# For operation precedence[1,1,4,2] = 1.0
# For operation precedence[1,1,4,3] = 1.0
# For operation precedence[1,1,4,4] = 1.0
# For operation precedence[1,1,4,5] = 1.0
# For operation precedence[1,1,4,6] = 1.0
# For operation precedence[1,2,1,1] = 0.0
# For operation precedence[1,2,1,2] = 0.0
# For operation precedence[1,2,1,3] = 1.0
# For operation precedence[1,2,1,4] = 1.0
# For operation precedence[1,2,1,5] = 1.0
# For operation precedence[1,2,1,6] = 1.0
# For operation precedence[1,2,2,1] = 0.0
# For operation precedence[1,2,2,2] = 1.0
# For operation precedence[1,2,2,3] = 1.0
# For operation precedence[1,2,2,4] = 1.0
# For operation precedence[1,2,2,5] = 1.0
# For operation precedence[1,2,2,6] = 1.0
# For operation precedence[1,2,3,1] = 0.0
# For operation precedence[1,2,3,2] = 1.0
# For operation precedence[1,2,3,3] = 1.0
# For operation precedence[1,2,3,4] = 1.0
# For operation precedence[1,2,3,5] = 1.0
# For operation precedence[1,2,3,6] = 1.0
# For operation precedence[1,2,4,1] = 0.0
# For operation precedence[1,2,4,2] = 0.0
# For operation precedence[1,2,4,3] = 1.0
# For operation precedence[1,2,4,4] = 1.0
# For operation precedence[1,2,4,5] = 1.0
# For operation precedence[1,2,4,6] = 1.0
# For operation precedence[1,3,1,1] = 0.0
# For operation precedence[1,3,1,2] = 0.0
# For operation precedence[1,3,1,3] = 0.0
# For operation precedence[1,3,1,4] = 1.0
# For operation precedence[1,3,1,5] = 1.0
# For operation precedence[1,3,1,6] = 1.0
# For operation precedence[1,3,2,1] = 0.0
# For operation precedence[1,3,2,2] = 0.0
# For operation precedence[1,3,2,3] = 0.0
# For operation precedence[1,3,2,4] = 1.0
# For operation precedence[1,3,2,5] = 1.0
# For operation precedence[1,3,2,6] = 1.0
# For operation precedence[1,3,3,1] = 0.0
# For operation precedence[1,3,3,2] = 0.0
# For operation precedence[1,3,3,3] = 0.0
# For operation precedence[1,3,3,4] = 1.0
# For operation precedence[1,3,3,5] = 1.0
# For operation precedence[1,3,3,6] = 1.0
# For operation precedence[1,3,4,1] = 0.0
# For operation precedence[1,3,4,2] = 0.0
# For operation precedence[1,3,4,3] = 0.0
# For operation precedence[1,3,4,4] = 1.0
# For operation precedence[1,3,4,5] = 1.0
# For operation precedence[1,3,4,6] = 1.0
# For operation precedence[1,4,1,1] = 0.0
# For operation precedence[1,4,1,2] = 0.0
# For operation precedence[1,4,1,3] = 0.0
# For operation precedence[1,4,1,4] = 0.0
# For operation precedence[1,4,1,5] = 1.0
# For operation precedence[1,4,1,6] = 1.0
# For operation precedence[1,4,2,1] = 0.0
# For operation precedence[1,4,2,2] = 0.0
# For operation precedence[1,4,2,3] = 0.0
# For operation precedence[1,4,2,4] = 0.0
# For operation precedence[1,4,2,5] = 1.0
# For operation precedence[1,4,2,6] = 1.0
# For operation precedence[1,4,3,1] = 0.0
# For operation precedence[1,4,3,2] = 0.0
# For operation precedence[1,4,3,3] = 0.0
# For operation precedence[1,4,3,4] = 1.0
# For operation precedence[1,4,3,5] = 1.0
# For operation precedence[1,4,3,6] = 1.0
# For operation precedence[1,4,4,1] = 0.0
# For operation precedence[1,4,4,2] = 0.0
# For operation precedence[1,4,4,3] = 0.0
# For operation precedence[1,4,4,4] = 0.0
# For operation precedence[1,4,4,5] = 1.0
# For operation precedence[1,4,4,6] = 1.0
# For operation precedence[1,5,1,1] = 0.0
# For operation precedence[1,5,1,2] = 0.0
# For operation precedence[1,5,1,3] = 0.0
# For operation precedence[1,5,1,4] = 0.0
# For operation precedence[1,5,1,5] = 0.0
# For operation precedence[1,5,1,6] = 1.0
# For operation precedence[1,5,2,1] = 0.0
# For operation precedence[1,5,2,2] = 0.0
# For operation precedence[1,5,2,3] = 0.0
# For operation precedence[1,5,2,4] = 0.0
# For operation precedence[1,5,2,5] = 0.0
# For operation precedence[1,5,2,6] = 1.0
# For operation precedence[1,5,3,1] = 0.0
# For operation precedence[1,5,3,2] = 0.0
# For operation precedence[1,5,3,3] = 0.0
# For operation precedence[1,5,3,4] = 0.0
# For operation precedence[1,5,3,5] = 0.0
# For operation precedence[1,5,3,6] = 1.0
# For operation precedence[1,5,4,1] = 0.0
# For operation precedence[1,5,4,2] = 0.0
# For operation precedence[1,5,4,3] = 0.0
# For operation precedence[1,5,4,4] = 0.0
# For operation precedence[1,5,4,5] = 0.0
# For operation precedence[1,5,4,6] = 1.0
# For operation precedence[1,6,1,1] = 0.0
# For operation precedence[1,6,1,2] = 0.0
# For operation precedence[1,6,1,3] = 0.0
# For operation precedence[1,6,1,4] = 0.0
# For operation precedence[1,6,1,5] = 0.0
# For operation precedence[1,6,1,6] = 0.0
# For operation precedence[1,6,2,1] = 0.0
# For operation precedence[1,6,2,2] = 0.0
# For operation precedence[1,6,2,3] = 0.0
# For operation precedence[1,6,2,4] = 0.0
# For operation precedence[1,6,2,5] = 0.0
# For operation precedence[1,6,2,6] = 0.0
# For operation precedence[1,6,3,1] = 0.0
# For operation precedence[1,6,3,2] = 0.0
# For operation precedence[1,6,3,3] = 0.0
# For operation precedence[1,6,3,4] = 0.0
# For operation precedence[1,6,3,5] = 0.0
# For operation precedence[1,6,3,6] = 0.0
# For operation precedence[1,6,4,1] = 0.0
# For operation precedence[1,6,4,2] = 0.0
# For operation precedence[1,6,4,3] = 0.0
# For operation precedence[1,6,4,4] = 0.0
# For operation precedence[1,6,4,5] = 0.0
# For operation precedence[1,6,4,6] = 0.0
# For operation precedence[2,1,1,1] = 1.0
# For operation precedence[2,1,1,2] = 1.0
# For operation precedence[2,1,1,3] = 1.0
# For operation precedence[2,1,1,4] = 1.0
# For operation precedence[2,1,1,5] = 1.0
# For operation precedence[2,1,1,6] = 1.0
# For operation precedence[2,1,2,1] = 0.0
# For operation precedence[2,1,2,2] = 1.0
# For operation precedence[2,1,2,3] = 1.0
# For operation precedence[2,1,2,4] = 1.0
# For operation precedence[2,1,2,5] = 1.0
# For operation precedence[2,1,2,6] = 1.0
# For operation precedence[2,1,3,1] = 1.0
# For operation precedence[2,1,3,2] = 1.0
# For operation precedence[2,1,3,3] = 1.0
# For operation precedence[2,1,3,4] = 1.0
# For operation precedence[2,1,3,5] = 1.0
# For operation precedence[2,1,3,6] = 1.0
# For operation precedence[2,1,4,1] = 1.0
# For operation precedence[2,1,4,2] = 1.0
# For operation precedence[2,1,4,3] = 1.0
# For operation precedence[2,1,4,4] = 1.0
# For operation precedence[2,1,4,5] = 1.0
# For operation precedence[2,1,4,6] = 1.0
# For operation precedence[2,2,1,1] = 0.0
# For operation precedence[2,2,1,2] = 0.0
# For operation precedence[2,2,1,3] = 1.0
# For operation precedence[2,2,1,4] = 1.0
# For operation precedence[2,2,1,5] = 1.0
# For operation precedence[2,2,1,6] = 1.0
# For operation precedence[2,2,2,1] = 0.0
# For operation precedence[2,2,2,2] = 0.0
# For operation precedence[2,2,2,3] = 1.0
# For operation precedence[2,2,2,4] = 1.0
# For operation precedence[2,2,2,5] = 1.0
# For operation precedence[2,2,2,6] = 1.0
# For operation precedence[2,2,3,1] = 0.0
# For operation precedence[2,2,3,2] = 1.0
# For operation precedence[2,2,3,3] = 1.0
# For operation precedence[2,2,3,4] = 1.0
# For operation precedence[2,2,3,5] = 1.0
# For operation precedence[2,2,3,6] = 1.0
# For operation precedence[2,2,4,1] = 0.0
# For operation precedence[2,2,4,2] = 0.0
# For operation precedence[2,2,4,3] = 1.0
# For operation precedence[2,2,4,4] = 1.0
# For operation precedence[2,2,4,5] = 1.0
# For operation precedence[2,2,4,6] = 1.0
# For operation precedence[2,3,1,1] = 0.0
# For operation precedence[2,3,1,2] = 0.0
# For operation precedence[2,3,1,3] = 1.0
# For operation precedence[2,3,1,4] = 1.0
# For operation precedence[2,3,1,5] = 1.0
# For operation precedence[2,3,1,6] = 1.0
# For operation precedence[2,3,2,1] = 0.0
# For operation precedence[2,3,2,2] = 0.0
# For operation precedence[2,3,2,3] = 0.0
# For operation precedence[2,3,2,4] = 1.0
# For operation precedence[2,3,2,5] = 1.0
# For operation precedence[2,3,2,6] = 1.0
# For operation precedence[2,3,3,1] = 0.0
# For operation precedence[2,3,3,2] = 0.0
# For operation precedence[2,3,3,3] = 0.0
# For operation precedence[2,3,3,4] = 1.0
# For operation precedence[2,3,3,5] = 1.0
# For operation precedence[2,3,3,6] = 1.0
# For operation precedence[2,3,4,1] = 0.0
# For operation precedence[2,3,4,2] = 0.0
# For operation precedence[2,3,4,3] = 0.0
# For operation precedence[2,3,4,4] = 1.0
# For operation precedence[2,3,4,5] = 1.0
# For operation precedence[2,3,4,6] = 1.0
# For operation precedence[2,4,1,1] = 0.0
# For operation precedence[2,4,1,2] = 0.0
# For operation precedence[2,4,1,3] = 0.0
# For operation precedence[2,4,1,4] = 1.0
# For operation precedence[2,4,1,5] = 1.0
# For operation precedence[2,4,1,6] = 1.0
# For operation precedence[2,4,2,1] = 0.0
# For operation precedence[2,4,2,2] = 0.0
# For operation precedence[2,4,2,3] = 0.0
# For operation precedence[2,4,2,4] = 0.0
# For operation precedence[2,4,2,5] = 1.0
# For operation precedence[2,4,2,6] = 1.0
# For operation precedence[2,4,3,1] = 0.0
# For operation precedence[2,4,3,2] = 0.0
# For operation precedence[2,4,3,3] = 0.0
# For operation precedence[2,4,3,4] = 1.0
# For operation precedence[2,4,3,5] = 1.0
# For operation precedence[2,4,3,6] = 1.0
# For operation precedence[2,4,4,1] = 0.0
# For operation precedence[2,4,4,2] = 0.0
# For operation precedence[2,4,4,3] = 0.0
# For operation precedence[2,4,4,4] = 0.0
# For operation precedence[2,4,4,5] = 1.0
# For operation precedence[2,4,4,6] = 1.0
# For operation precedence[2,5,1,1] = 0.0
# For operation precedence[2,5,1,2] = 0.0
# For operation precedence[2,5,1,3] = 0.0
# For operation precedence[2,5,1,4] = 0.0
# For operation precedence[2,5,1,5] = 1.0
# For operation precedence[2,5,1,6] = 1.0
# For operation precedence[2,5,2,1] = 0.0
# For operation precedence[2,5,2,2] = 0.0
# For operation precedence[2,5,2,3] = 0.0
# For operation precedence[2,5,2,4] = 0.0
# For operation precedence[2,5,2,5] = 0.0
# For operation precedence[2,5,2,6] = 1.0
# For operation precedence[2,5,3,1] = 0.0
# For operation precedence[2,5,3,2] = 0.0
# For operation precedence[2,5,3,3] = 0.0
# For operation precedence[2,5,3,4] = 0.0
# For operation precedence[2,5,3,5] = 1.0
# For operation precedence[2,5,3,6] = 1.0
# For operation precedence[2,5,4,1] = 0.0
# For operation precedence[2,5,4,2] = 0.0
# For operation precedence[2,5,4,3] = 0.0
# For operation precedence[2,5,4,4] = 0.0
# For operation precedence[2,5,4,5] = 0.0
# For operation precedence[2,5,4,6] = 1.0
# For operation precedence[2,6,1,1] = 0.0
# For operation precedence[2,6,1,2] = 0.0
# For operation precedence[2,6,1,3] = 0.0
# For operation precedence[2,6,1,4] = 0.0
# For operation precedence[2,6,1,5] = 0.0
# For operation precedence[2,6,1,6] = 1.0
# For operation precedence[2,6,2,1] = 0.0
# For operation precedence[2,6,2,2] = 0.0
# For operation precedence[2,6,2,3] = 0.0
# For operation precedence[2,6,2,4] = 0.0
# For operation precedence[2,6,2,5] = 0.0
# For operation precedence[2,6,2,6] = 0.0
# For operation precedence[2,6,3,1] = 0.0
# For operation precedence[2,6,3,2] = 0.0
# For operation precedence[2,6,3,3] = 0.0
# For operation precedence[2,6,3,4] = 0.0
# For operation precedence[2,6,3,5] = 0.0
# For operation precedence[2,6,3,6] = 0.0
# For operation precedence[2,6,4,1] = 0.0
# For operation precedence[2,6,4,2] = 0.0
# For operation precedence[2,6,4,3] = 0.0
# For operation precedence[2,6,4,4] = 0.0
# For operation precedence[2,6,4,5] = 0.0
# For operation precedence[2,6,4,6] = 0.0
# For operation precedence[3,1,1,1] = 1.0
# For operation precedence[3,1,1,2] = 1.0
# For operation precedence[3,1,1,3] = 1.0
# For operation precedence[3,1,1,4] = 1.0
# For operation precedence[3,1,1,5] = 1.0
# For operation precedence[3,1,1,6] = 1.0
# For operation precedence[3,1,2,1] = 0.0
# For operation precedence[3,1,2,2] = 1.0
# For operation precedence[3,1,2,3] = 1.0
# For operation precedence[3,1,2,4] = 1.0
# For operation precedence[3,1,2,5] = 1.0
# For operation precedence[3,1,2,6] = 1.0
# For operation precedence[3,1,3,1] = 0.0
# For operation precedence[3,1,3,2] = 1.0
# For operation precedence[3,1,3,3] = 1.0
# For operation precedence[3,1,3,4] = 1.0
# For operation precedence[3,1,3,5] = 1.0
# For operation precedence[3,1,3,6] = 1.0
# For operation precedence[3,1,4,1] = 1.0
# For operation precedence[3,1,4,2] = 1.0
# For operation precedence[3,1,4,3] = 1.0
# For operation precedence[3,1,4,4] = 1.0
# For operation precedence[3,1,4,5] = 1.0
# For operation precedence[3,1,4,6] = 1.0
# For operation precedence[3,2,1,1] = 0.0
# For operation precedence[3,2,1,2] = 0.0
# For operation precedence[3,2,1,3] = 1.0
# For operation precedence[3,2,1,4] = 1.0
# For operation precedence[3,2,1,5] = 1.0
# For operation precedence[3,2,1,6] = 1.0
# For operation precedence[3,2,2,1] = 0.0
# For operation precedence[3,2,2,2] = 0.0
# For operation precedence[3,2,2,3] = 1.0
# For operation precedence[3,2,2,4] = 1.0
# For operation precedence[3,2,2,5] = 1.0
# For operation precedence[3,2,2,6] = 1.0
# For operation precedence[3,2,3,1] = 0.0
# For operation precedence[3,2,3,2] = 0.0
# For operation precedence[3,2,3,3] = 1.0
# For operation precedence[3,2,3,4] = 1.0
# For operation precedence[3,2,3,5] = 1.0
# For operation precedence[3,2,3,6] = 1.0
# For operation precedence[3,2,4,1] = 0.0
# For operation precedence[3,2,4,2] = 0.0
# For operation precedence[3,2,4,3] = 1.0
# For operation precedence[3,2,4,4] = 1.0
# For operation precedence[3,2,4,5] = 1.0
# For operation precedence[3,2,4,6] = 1.0
# For operation precedence[3,3,1,1] = 0.0
# For operation precedence[3,3,1,2] = 0.0
# For operation precedence[3,3,1,3] = 1.0
# For operation precedence[3,3,1,4] = 1.0
# For operation precedence[3,3,1,5] = 1.0
# For operation precedence[3,3,1,6] = 1.0
# For operation precedence[3,3,2,1] = 0.0
# For operation precedence[3,3,2,2] = 0.0
# For operation precedence[3,3,2,3] = 1.0
# For operation precedence[3,3,2,4] = 1.0
# For operation precedence[3,3,2,5] = 1.0
# For operation precedence[3,3,2,6] = 1.0
# For operation precedence[3,3,3,1] = 0.0
# For operation precedence[3,3,3,2] = 0.0
# For operation precedence[3,3,3,3] = 0.0
# For operation precedence[3,3,3,4] = 1.0
# For operation precedence[3,3,3,5] = 1.0
# For operation precedence[3,3,3,6] = 1.0
# For operation precedence[3,3,4,1] = 0.0
# For operation precedence[3,3,4,2] = 0.0
# For operation precedence[3,3,4,3] = 0.0
# For operation precedence[3,3,4,4] = 1.0
# For operation precedence[3,3,4,5] = 1.0
# For operation precedence[3,3,4,6] = 1.0
# For operation precedence[3,4,1,1] = 0.0
# For operation precedence[3,4,1,2] = 0.0
# For operation precedence[3,4,1,3] = 0.0
# For operation precedence[3,4,1,4] = 0.0
# For operation precedence[3,4,1,5] = 1.0
# For operation precedence[3,4,1,6] = 1.0
# For operation precedence[3,4,2,1] = 0.0
# For operation precedence[3,4,2,2] = 0.0
# For operation precedence[3,4,2,3] = 0.0
# For operation precedence[3,4,2,4] = 0.0
# For operation precedence[3,4,2,5] = 1.0
# For operation precedence[3,4,2,6] = 1.0
# For operation precedence[3,4,3,1] = 0.0
# For operation precedence[3,4,3,2] = 0.0
# For operation precedence[3,4,3,3] = 0.0
# For operation precedence[3,4,3,4] = 0.0
# For operation precedence[3,4,3,5] = 1.0
# For operation precedence[3,4,3,6] = 1.0
# For operation precedence[3,4,4,1] = 0.0
# For operation precedence[3,4,4,2] = 0.0
# For operation precedence[3,4,4,3] = 0.0
# For operation precedence[3,4,4,4] = 0.0
# For operation precedence[3,4,4,5] = 1.0
# For operation precedence[3,4,4,6] = 1.0
# For operation precedence[3,5,1,1] = 0.0
# For operation precedence[3,5,1,2] = 0.0
# For operation precedence[3,5,1,3] = 0.0
# For operation precedence[3,5,1,4] = 0.0
# For operation precedence[3,5,1,5] = 1.0
# For operation precedence[3,5,1,6] = 1.0
# For operation precedence[3,5,2,1] = 0.0
# For operation precedence[3,5,2,2] = 0.0
# For operation precedence[3,5,2,3] = 0.0
# For operation precedence[3,5,2,4] = 0.0
# For operation precedence[3,5,2,5] = 0.0
# For operation precedence[3,5,2,6] = 1.0
# For operation precedence[3,5,3,1] = 0.0
# For operation precedence[3,5,3,2] = 0.0
# For operation precedence[3,5,3,3] = 0.0
# For operation precedence[3,5,3,4] = 0.0
# For operation precedence[3,5,3,5] = 0.0
# For operation precedence[3,5,3,6] = 1.0
# For operation precedence[3,5,4,1] = 0.0
# For operation precedence[3,5,4,2] = 0.0
# For operation precedence[3,5,4,3] = 0.0
# For operation precedence[3,5,4,4] = 0.0
# For operation precedence[3,5,4,5] = 0.0
# For operation precedence[3,5,4,6] = 1.0
# For operation precedence[3,6,1,1] = 0.0
# For operation precedence[3,6,1,2] = 0.0
# For operation precedence[3,6,1,3] = 0.0
# For operation precedence[3,6,1,4] = 0.0
# For operation precedence[3,6,1,5] = 0.0
# For operation precedence[3,6,1,6] = 1.0
# For operation precedence[3,6,2,1] = 0.0
# For operation precedence[3,6,2,2] = 0.0
# For operation precedence[3,6,2,3] = 0.0
# For operation precedence[3,6,2,4] = 0.0
# For operation precedence[3,6,2,5] = 0.0
# For operation precedence[3,6,2,6] = 1.0
# For operation precedence[3,6,3,1] = 0.0
# For operation precedence[3,6,3,2] = 0.0
# For operation precedence[3,6,3,3] = 0.0
# For operation precedence[3,6,3,4] = 0.0
# For operation precedence[3,6,3,5] = 0.0
# For operation precedence[3,6,3,6] = 0.0
# For operation precedence[3,6,4,1] = 0.0
# For operation precedence[3,6,4,2] = 0.0
# For operation precedence[3,6,4,3] = 0.0
# For operation precedence[3,6,4,4] = 0.0
# For operation precedence[3,6,4,5] = 0.0
# For operation precedence[3,6,4,6] = 1.0
# For operation precedence[4,1,1,1] = 1.0
# For operation precedence[4,1,1,2] = 1.0
# For operation precedence[4,1,1,3] = 1.0
# For operation precedence[4,1,1,4] = 1.0
# For operation precedence[4,1,1,5] = 1.0
# For operation precedence[4,1,1,6] = 1.0
# For operation precedence[4,1,2,1] = 0.0
# For operation precedence[4,1,2,2] = 1.0
# For operation precedence[4,1,2,3] = 1.0
# For operation precedence[4,1,2,4] = 1.0
# For operation precedence[4,1,2,5] = 1.0
# For operation precedence[4,1,2,6] = 1.0
# For operation precedence[4,1,3,1] = 0.0
# For operation precedence[4,1,3,2] = 1.0
# For operation precedence[4,1,3,3] = 1.0
# For operation precedence[4,1,3,4] = 1.0
# For operation precedence[4,1,3,5] = 1.0
# For operation precedence[4,1,3,6] = 1.0
# For operation precedence[4,1,4,1] = 0.0
# For operation precedence[4,1,4,2] = 1.0
# For operation precedence[4,1,4,3] = 1.0
# For operation precedence[4,1,4,4] = 1.0
# For operation precedence[4,1,4,5] = 1.0
# For operation precedence[4,1,4,6] = 1.0
# For operation precedence[4,2,1,1] = 0.0
# For operation precedence[4,2,1,2] = 1.0
# For operation precedence[4,2,1,3] = 1.0
# For operation precedence[4,2,1,4] = 1.0
# For operation precedence[4,2,1,5] = 1.0
# For operation precedence[4,2,1,6] = 1.0
# For operation precedence[4,2,2,1] = 0.0
# For operation precedence[4,2,2,2] = 1.0
# For operation precedence[4,2,2,3] = 1.0
# For operation precedence[4,2,2,4] = 1.0
# For operation precedence[4,2,2,5] = 1.0
# For operation precedence[4,2,2,6] = 1.0
# For operation precedence[4,2,3,1] = 0.0
# For operation precedence[4,2,3,2] = 1.0
# For operation precedence[4,2,3,3] = 1.0
# For operation precedence[4,2,3,4] = 1.0
# For operation precedence[4,2,3,5] = 1.0
# For operation precedence[4,2,3,6] = 1.0
# For operation precedence[4,2,4,1] = 0.0
# For operation precedence[4,2,4,2] = 0.0
# For operation precedence[4,2,4,3] = 1.0
# For operation precedence[4,2,4,4] = 1.0
# For operation precedence[4,2,4,5] = 1.0
# For operation precedence[4,2,4,6] = 1.0
# For operation precedence[4,3,1,1] = 0.0
# For operation precedence[4,3,1,2] = 0.0
# For operation precedence[4,3,1,3] = 1.0
# For operation precedence[4,3,1,4] = 1.0
# For operation precedence[4,3,1,5] = 1.0
# For operation precedence[4,3,1,6] = 1.0
# For operation precedence[4,3,2,1] = 0.0
# For operation precedence[4,3,2,2] = 0.0
# For operation precedence[4,3,2,3] = 1.0
# For operation precedence[4,3,2,4] = 1.0
# For operation precedence[4,3,2,5] = 1.0
# For operation precedence[4,3,2,6] = 1.0
# For operation precedence[4,3,3,1] = 0.0
# For operation precedence[4,3,3,2] = 0.0
# For operation precedence[4,3,3,3] = 1.0
# For operation precedence[4,3,3,4] = 1.0
# For operation precedence[4,3,3,5] = 1.0
# For operation precedence[4,3,3,6] = 1.0
# For operation precedence[4,3,4,1] = 0.0
# For operation precedence[4,3,4,2] = 0.0
# For operation precedence[4,3,4,3] = 0.0
# For operation precedence[4,3,4,4] = 1.0
# For operation precedence[4,3,4,5] = 1.0
# For operation precedence[4,3,4,6] = 1.0
# For operation precedence[4,4,1,1] = 0.0
# For operation precedence[4,4,1,2] = 0.0
# For operation precedence[4,4,1,3] = 0.0
# For operation precedence[4,4,1,4] = 1.0
# For operation precedence[4,4,1,5] = 1.0
# For operation precedence[4,4,1,6] = 1.0
# For operation precedence[4,4,2,1] = 0.0
# For operation precedence[4,4,2,2] = 0.0
# For operation precedence[4,4,2,3] = 0.0
# For operation precedence[4,4,2,4] = 1.0
# For operation precedence[4,4,2,5] = 1.0
# For operation precedence[4,4,2,6] = 1.0
# For operation precedence[4,4,3,1] = 0.0
# For operation precedence[4,4,3,2] = 0.0
# For operation precedence[4,4,3,3] = 0.0
# For operation precedence[4,4,3,4] = 1.0
# For operation precedence[4,4,3,5] = 1.0
# For operation precedence[4,4,3,6] = 1.0
# For operation precedence[4,4,4,1] = 0.0
# For operation precedence[4,4,4,2] = 0.0
# For operation precedence[4,4,4,3] = 0.0
# For operation precedence[4,4,4,4] = 0.0
# For operation precedence[4,4,4,5] = 1.0
# For operation precedence[4,4,4,6] = 1.0
# For operation precedence[4,5,1,1] = 0.0
# For operation precedence[4,5,1,2] = 0.0
# For operation precedence[4,5,1,3] = 0.0
# For operation precedence[4,5,1,4] = 0.0
# For operation precedence[4,5,1,5] = 1.0
# For operation precedence[4,5,1,6] = 1.0
# For operation precedence[4,5,2,1] = 0.0
# For operation precedence[4,5,2,2] = 0.0
# For operation precedence[4,5,2,3] = 0.0
# For operation precedence[4,5,2,4] = 0.0
# For operation precedence[4,5,2,5] = 1.0
# For operation precedence[4,5,2,6] = 1.0
# For operation precedence[4,5,3,1] = 0.0
# For operation precedence[4,5,3,2] = 0.0
# For operation precedence[4,5,3,3] = 0.0
# For operation precedence[4,5,3,4] = 0.0
# For operation precedence[4,5,3,5] = 1.0
# For operation precedence[4,5,3,6] = 1.0
# For operation precedence[4,5,4,1] = 0.0
# For operation precedence[4,5,4,2] = 0.0
# For operation precedence[4,5,4,3] = 0.0
# For operation precedence[4,5,4,4] = 0.0
# For operation precedence[4,5,4,5] = 0.0
# For operation precedence[4,5,4,6] = 1.0
# For operation precedence[4,6,1,1] = 0.0
# For operation precedence[4,6,1,2] = 0.0
# For operation precedence[4,6,1,3] = 0.0
# For operation precedence[4,6,1,4] = 0.0
# For operation precedence[4,6,1,5] = 0.0
# For operation precedence[4,6,1,6] = 1.0
# For operation precedence[4,6,2,1] = 0.0
# For operation precedence[4,6,2,2] = 0.0
# For operation precedence[4,6,2,3] = 0.0
# For operation precedence[4,6,2,4] = 0.0
# For operation precedence[4,6,2,5] = 0.0
# For operation precedence[4,6,2,6] = 1.0
# For operation precedence[4,6,3,1] = 0.0
# For operation precedence[4,6,3,2] = 0.0
# For operation precedence[4,6,3,3] = 0.0
# For operation precedence[4,6,3,4] = 0.0
# For operation precedence[4,6,3,5] = 0.0
# For operation precedence[4,6,3,6] = 0.0
# For operation precedence[4,6,4,1] = 0.0
# For operation precedence[4,6,4,2] = 0.0
# For operation precedence[4,6,4,3] = 0.0
# For operation precedence[4,6,4,4] = 0.0
# For operation precedence[4,6,4,5] = 0.0
# For operation precedence[4,6,4,6] = 0.0
# For transportation precedence[1,1,1,1] = 0.0
# For transportation precedence[1,1,1,2] = 0.0
# For transportation precedence[1,1,1,3] = 1.0
# For transportation precedence[1,1,1,4] = 1.0
# For transportation precedence[1,1,1,5] = 1.0
# For transportation precedence[1,1,1,6] = 0.0
# For transportation precedence[1,1,2,1] = 0.0
# For transportation precedence[1,1,2,2] = 0.0
# For transportation precedence[1,1,2,3] = 0.0
# For transportation precedence[1,1,2,4] = 0.0
# For transportation precedence[1,1,2,5] = 0.0
# For transportation precedence[1,1,2,6] = 0.0
# For transportation precedence[1,1,3,1] = 0.0
# For transportation precedence[1,1,3,2] = 1.0
# For transportation precedence[1,1,3,3] = 0.0
# For transportation precedence[1,1,3,4] = 1.0
# For transportation precedence[1,1,3,5] = 1.0
# For transportation precedence[1,1,3,6] = 0.0
# For transportation precedence[1,1,4,1] = 0.0
# For transportation precedence[1,1,4,2] = 0.0
# For transportation precedence[1,1,4,3] = 0.0
# For transportation precedence[1,1,4,4] = 0.0
# For transportation precedence[1,1,4,5] = 0.0
# For transportation precedence[1,1,4,6] = 0.0
# For transportation precedence[1,2,1,1] = 1.0
# For transportation precedence[1,2,1,2] = 0.0
# For transportation precedence[1,2,1,3] = 1.0
# For transportation precedence[1,2,1,4] = 1.0
# For transportation precedence[1,2,1,5] = 1.0
# For transportation precedence[1,2,1,6] = 1.0
# For transportation precedence[1,2,2,1] = 0.0
# For transportation precedence[1,2,2,2] = 0.0
# For transportation precedence[1,2,2,3] = 1.0
# For transportation precedence[1,2,2,4] = 0.0
# For transportation precedence[1,2,2,5] = 0.0
# For transportation precedence[1,2,2,6] = 1.0
# For transportation precedence[1,2,3,1] = 0.0
# For transportation precedence[1,2,3,2] = 1.0
# For transportation precedence[1,2,3,3] = 0.0
# For transportation precedence[1,2,3,4] = 1.0
# For transportation precedence[1,2,3,5] = 1.0
# For transportation precedence[1,2,3,6] = 0.0
# For transportation precedence[1,2,4,1] = 0.0
# For transportation precedence[1,2,4,2] = 0.0
# For transportation precedence[1,2,4,3] = 0.0
# For transportation precedence[1,2,4,4] = 0.0
# For transportation precedence[1,2,4,5] = 0.0
# For transportation precedence[1,2,4,6] = 0.0
# For transportation precedence[1,3,1,1] = 0.0
# For transportation precedence[1,3,1,2] = 0.0
# For transportation precedence[1,3,1,3] = 0.0
# For transportation precedence[1,3,1,4] = 1.0
# For transportation precedence[1,3,1,5] = 1.0
# For transportation precedence[1,3,1,6] = 1.0
# For transportation precedence[1,3,2,1] = 1.0
# For transportation precedence[1,3,2,2] = 0.0
# For transportation precedence[1,3,2,3] = 0.0
# For transportation precedence[1,3,2,4] = 0.0
# For transportation precedence[1,3,2,5] = 0.0
# For transportation precedence[1,3,2,6] = 1.0
# For transportation precedence[1,3,3,1] = 0.0
# For transportation precedence[1,3,3,2] = 0.0
# For transportation precedence[1,3,3,3] = 0.0
# For transportation precedence[1,3,3,4] = 1.0
# For transportation precedence[1,3,3,5] = 1.0
# For transportation precedence[1,3,3,6] = 0.0
# For transportation precedence[1,3,4,1] = 0.0
# For transportation precedence[1,3,4,2] = 0.0
# For transportation precedence[1,3,4,3] = 0.0
# For transportation precedence[1,3,4,4] = 0.0
# For transportation precedence[1,3,4,5] = 0.0
# For transportation precedence[1,3,4,6] = 0.0
# For transportation precedence[1,4,1,1] = 0.0
# For transportation precedence[1,4,1,2] = 0.0
# For transportation precedence[1,4,1,3] = 0.0
# For transportation precedence[1,4,1,4] = 0.0
# For transportation precedence[1,4,1,5] = 1.0
# For transportation precedence[1,4,1,6] = 1.0
# For transportation precedence[1,4,2,1] = 0.0
# For transportation precedence[1,4,2,2] = 0.0
# For transportation precedence[1,4,2,3] = 0.0
# For transportation precedence[1,4,2,4] = 0.0
# For transportation precedence[1,4,2,5] = 0.0
# For transportation precedence[1,4,2,6] = 1.0
# For transportation precedence[1,4,3,1] = 0.0
# For transportation precedence[1,4,3,2] = 0.0
# For transportation precedence[1,4,3,3] = 0.0
# For transportation precedence[1,4,3,4] = 0.0
# For transportation precedence[1,4,3,5] = 1.0
# For transportation precedence[1,4,3,6] = 0.0
# For transportation precedence[1,4,4,1] = 0.0
# For transportation precedence[1,4,4,2] = 0.0
# For transportation precedence[1,4,4,3] = 0.0
# For transportation precedence[1,4,4,4] = 0.0
# For transportation precedence[1,4,4,5] = 0.0
# For transportation precedence[1,4,4,6] = 0.0
# For transportation precedence[1,5,1,1] = 0.0
# For transportation precedence[1,5,1,2] = 0.0
# For transportation precedence[1,5,1,3] = 0.0
# For transportation precedence[1,5,1,4] = 0.0
# For transportation precedence[1,5,1,5] = 0.0
# For transportation precedence[1,5,1,6] = 1.0
# For transportation precedence[1,5,2,1] = 1.0
# For transportation precedence[1,5,2,2] = 0.0
# For transportation precedence[1,5,2,3] = 0.0
# For transportation precedence[1,5,2,4] = 0.0
# For transportation precedence[1,5,2,5] = 0.0
# For transportation precedence[1,5,2,6] = 1.0
# For transportation precedence[1,5,3,1] = 0.0
# For transportation precedence[1,5,3,2] = 0.0
# For transportation precedence[1,5,3,3] = 0.0
# For transportation precedence[1,5,3,4] = 0.0
# For transportation precedence[1,5,3,5] = 0.0
# For transportation precedence[1,5,3,6] = 0.0
# For transportation precedence[1,5,4,1] = 0.0
# For transportation precedence[1,5,4,2] = 0.0
# For transportation precedence[1,5,4,3] = 0.0
# For transportation precedence[1,5,4,4] = 0.0
# For transportation precedence[1,5,4,5] = 0.0
# For transportation precedence[1,5,4,6] = 0.0
# For transportation precedence[1,6,1,1] = 1.0
# For transportation precedence[1,6,1,2] = 0.0
# For transportation precedence[1,6,1,3] = 0.0
# For transportation precedence[1,6,1,4] = 0.0
# For transportation precedence[1,6,1,5] = 0.0
# For transportation precedence[1,6,1,6] = 0.0
# For transportation precedence[1,6,2,1] = 0.0
# For transportation precedence[1,6,2,2] = 0.0
# For transportation precedence[1,6,2,3] = 0.0
# For transportation precedence[1,6,2,4] = 0.0
# For transportation precedence[1,6,2,5] = 0.0
# For transportation precedence[1,6,2,6] = 0.0
# For transportation precedence[1,6,3,1] = 0.0
# For transportation precedence[1,6,3,2] = 0.0
# For transportation precedence[1,6,3,3] = 0.0
# For transportation precedence[1,6,3,4] = 0.0
# For transportation precedence[1,6,3,5] = 0.0
# For transportation precedence[1,6,3,6] = 0.0
# For transportation precedence[1,6,4,1] = 0.0
# For transportation precedence[1,6,4,2] = 0.0
# For transportation precedence[1,6,4,3] = 0.0
# For transportation precedence[1,6,4,4] = 0.0
# For transportation precedence[1,6,4,5] = 0.0
# For transportation precedence[1,6,4,6] = 0.0
# For transportation precedence[2,1,1,1] = 1.0
# For transportation precedence[2,1,1,2] = 1.0
# For transportation precedence[2,1,1,3] = 0.0
# For transportation precedence[2,1,1,4] = 1.0
# For transportation precedence[2,1,1,5] = 0.0
# For transportation precedence[2,1,1,6] = 1.0
# For transportation precedence[2,1,2,1] = 0.0
# For transportation precedence[2,1,2,2] = 0.0
# For transportation precedence[2,1,2,3] = 1.0
# For transportation precedence[2,1,2,4] = 0.0
# For transportation precedence[2,1,2,5] = 0.0
# For transportation precedence[2,1,2,6] = 0.0
# For transportation precedence[2,1,3,1] = 0.0
# For transportation precedence[2,1,3,2] = 0.0
# For transportation precedence[2,1,3,3] = 0.0
# For transportation precedence[2,1,3,4] = 1.0
# For transportation precedence[2,1,3,5] = 1.0
# For transportation precedence[2,1,3,6] = 0.0
# For transportation precedence[2,1,4,1] = 0.0
# For transportation precedence[2,1,4,2] = 0.0
# For transportation precedence[2,1,4,3] = 0.0
# For transportation precedence[2,1,4,4] = 0.0
# For transportation precedence[2,1,4,5] = 0.0
# For transportation precedence[2,1,4,6] = 0.0
# For transportation precedence[2,2,1,1] = 0.0
# For transportation precedence[2,2,1,2] = 0.0
# For transportation precedence[2,2,1,3] = 0.0
# For transportation precedence[2,2,1,4] = 0.0
# For transportation precedence[2,2,1,5] = 0.0
# For transportation precedence[2,2,1,6] = 0.0
# For transportation precedence[2,2,2,1] = 0.0
# For transportation precedence[2,2,2,2] = 0.0
# For transportation precedence[2,2,2,3] = 0.0
# For transportation precedence[2,2,2,4] = 1.0
# For transportation precedence[2,2,2,5] = 1.0
# For transportation precedence[2,2,2,6] = 0.0
# For transportation precedence[2,2,3,1] = 0.0
# For transportation precedence[2,2,3,2] = 0.0
# For transportation precedence[2,2,3,3] = 1.0
# For transportation precedence[2,2,3,4] = 0.0
# For transportation precedence[2,2,3,5] = 0.0
# For transportation precedence[2,2,3,6] = 1.0
# For transportation precedence[2,2,4,1] = 1.0
# For transportation precedence[2,2,4,2] = 1.0
# For transportation precedence[2,2,4,3] = 1.0
# For transportation precedence[2,2,4,4] = 1.0
# For transportation precedence[2,2,4,5] = 1.0
# For transportation precedence[2,2,4,6] = 1.0
# For transportation precedence[2,3,1,1] = 1.0
# For transportation precedence[2,3,1,2] = 0.0
# For transportation precedence[2,3,1,3] = 1.0
# For transportation precedence[2,3,1,4] = 1.0
# For transportation precedence[2,3,1,5] = 1.0
# For transportation precedence[2,3,1,6] = 1.0
# For transportation precedence[2,3,2,1] = 0.0
# For transportation precedence[2,3,2,2] = 0.0
# For transportation precedence[2,3,2,3] = 0.0
# For transportation precedence[2,3,2,4] = 0.0
# For transportation precedence[2,3,2,5] = 0.0
# For transportation precedence[2,3,2,6] = 1.0
# For transportation precedence[2,3,3,1] = 0.0
# For transportation precedence[2,3,3,2] = 0.0
# For transportation precedence[2,3,3,3] = 0.0
# For transportation precedence[2,3,3,4] = 1.0
# For transportation precedence[2,3,3,5] = 1.0
# For transportation precedence[2,3,3,6] = 0.0
# For transportation precedence[2,3,4,1] = 0.0
# For transportation precedence[2,3,4,2] = 0.0
# For transportation precedence[2,3,4,3] = 0.0
# For transportation precedence[2,3,4,4] = 0.0
# For transportation precedence[2,3,4,5] = 0.0
# For transportation precedence[2,3,4,6] = 0.0
# For transportation precedence[2,4,1,1] = 0.0
# For transportation precedence[2,4,1,2] = 0.0
# For transportation precedence[2,4,1,3] = 0.0
# For transportation precedence[2,4,1,4] = 0.0
# For transportation precedence[2,4,1,5] = 0.0
# For transportation precedence[2,4,1,6] = 0.0
# For transportation precedence[2,4,2,1] = 0.0
# For transportation precedence[2,4,2,2] = 0.0
# For transportation precedence[2,4,2,3] = 0.0
# For transportation precedence[2,4,2,4] = 0.0
# For transportation precedence[2,4,2,5] = 1.0
# For transportation precedence[2,4,2,6] = 0.0
# For transportation precedence[2,4,3,1] = 0.0
# For transportation precedence[2,4,3,2] = 0.0
# For transportation precedence[2,4,3,3] = 0.0
# For transportation precedence[2,4,3,4] = 0.0
# For transportation precedence[2,4,3,5] = 0.0
# For transportation precedence[2,4,3,6] = 1.0
# For transportation precedence[2,4,4,1] = 1.0
# For transportation precedence[2,4,4,2] = 0.0
# For transportation precedence[2,4,4,3] = 0.0
# For transportation precedence[2,4,4,4] = 0.0
# For transportation precedence[2,4,4,5] = 1.0
# For transportation precedence[2,4,4,6] = 1.0
# For transportation precedence[2,5,1,1] = 0.0
# For transportation precedence[2,5,1,2] = 0.0
# For transportation precedence[2,5,1,3] = 0.0
# For transportation precedence[2,5,1,4] = 0.0
# For transportation precedence[2,5,1,5] = 0.0
# For transportation precedence[2,5,1,6] = 0.0
# For transportation precedence[2,5,2,1] = 0.0
# For transportation precedence[2,5,2,2] = 0.0
# For transportation precedence[2,5,2,3] = 0.0
# For transportation precedence[2,5,2,4] = 0.0
# For transportation precedence[2,5,2,5] = 0.0
# For transportation precedence[2,5,2,6] = 0.0
# For transportation precedence[2,5,3,1] = 0.0
# For transportation precedence[2,5,3,2] = 0.0
# For transportation precedence[2,5,3,3] = 0.0
# For transportation precedence[2,5,3,4] = 0.0
# For transportation precedence[2,5,3,5] = 0.0
# For transportation precedence[2,5,3,6] = 1.0
# For transportation precedence[2,5,4,1] = 0.0
# For transportation precedence[2,5,4,2] = 0.0
# For transportation precedence[2,5,4,3] = 0.0
# For transportation precedence[2,5,4,4] = 0.0
# For transportation precedence[2,5,4,5] = 0.0
# For transportation precedence[2,5,4,6] = 1.0
# For transportation precedence[2,6,1,1] = 1.0
# For transportation precedence[2,6,1,2] = 0.0
# For transportation precedence[2,6,1,3] = 0.0
# For transportation precedence[2,6,1,4] = 0.0
# For transportation precedence[2,6,1,5] = 0.0
# For transportation precedence[2,6,1,6] = 1.0
# For transportation precedence[2,6,2,1] = 1.0
# For transportation precedence[2,6,2,2] = 0.0
# For transportation precedence[2,6,2,3] = 0.0
# For transportation precedence[2,6,2,4] = 0.0
# For transportation precedence[2,6,2,5] = 0.0
# For transportation precedence[2,6,2,6] = 0.0
# For transportation precedence[2,6,3,1] = 0.0
# For transportation precedence[2,6,3,2] = 0.0
# For transportation precedence[2,6,3,3] = 0.0
# For transportation precedence[2,6,3,4] = 0.0
# For transportation precedence[2,6,3,5] = 0.0
# For transportation precedence[2,6,3,6] = 0.0
# For transportation precedence[2,6,4,1] = 0.0
# For transportation precedence[2,6,4,2] = 0.0
# For transportation precedence[2,6,4,3] = 0.0
# For transportation precedence[2,6,4,4] = 0.0
# For transportation precedence[2,6,4,5] = 0.0
# For transportation precedence[2,6,4,6] = 0.0
# For transportation precedence[3,1,1,1] = 0.0
# For transportation precedence[3,1,1,2] = 0.0
# For transportation precedence[3,1,1,3] = 0.0
# For transportation precedence[3,1,1,4] = 0.0
# For transportation precedence[3,1,1,5] = 0.0
# For transportation precedence[3,1,1,6] = 0.0
# For transportation precedence[3,1,2,1] = 0.0
# For transportation precedence[3,1,2,2] = 1.0
# For transportation precedence[3,1,2,3] = 0.0
# For transportation precedence[3,1,2,4] = 1.0
# For transportation precedence[3,1,2,5] = 1.0
# For transportation precedence[3,1,2,6] = 0.0
# For transportation precedence[3,1,3,1] = 0.0
# For transportation precedence[3,1,3,2] = 0.0
# For transportation precedence[3,1,3,3] = 0.0
# For transportation precedence[3,1,3,4] = 0.0
# For transportation precedence[3,1,3,5] = 0.0
# For transportation precedence[3,1,3,6] = 1.0
# For transportation precedence[3,1,4,1] = 0.0
# For transportation precedence[3,1,4,2] = 0.0
# For transportation precedence[3,1,4,3] = 1.0
# For transportation precedence[3,1,4,4] = 1.0
# For transportation precedence[3,1,4,5] = 0.0
# For transportation precedence[3,1,4,6] = 0.0
# For transportation precedence[3,2,1,1] = 0.0
# For transportation precedence[3,2,1,2] = 0.0
# For transportation precedence[3,2,1,3] = 1.0
# For transportation precedence[3,2,1,4] = 1.0
# For transportation precedence[3,2,1,5] = 1.0
# For transportation precedence[3,2,1,6] = 1.0
# For transportation precedence[3,2,2,1] = 1.0
# For transportation precedence[3,2,2,2] = 0.0
# For transportation precedence[3,2,2,3] = 1.0
# For transportation precedence[3,2,2,4] = 0.0
# For transportation precedence[3,2,2,5] = 0.0
# For transportation precedence[3,2,2,6] = 1.0
# For transportation precedence[3,2,3,1] = 0.0
# For transportation precedence[3,2,3,2] = 0.0
# For transportation precedence[3,2,3,3] = 0.0
# For transportation precedence[3,2,3,4] = 1.0
# For transportation precedence[3,2,3,5] = 1.0
# For transportation precedence[3,2,3,6] = 0.0
# For transportation precedence[3,2,4,1] = 0.0
# For transportation precedence[3,2,4,2] = 0.0
# For transportation precedence[3,2,4,3] = 0.0
# For transportation precedence[3,2,4,4] = 0.0
# For transportation precedence[3,2,4,5] = 0.0
# For transportation precedence[3,2,4,6] = 0.0
# For transportation precedence[3,3,1,1] = 0.0
# For transportation precedence[3,3,1,2] = 0.0
# For transportation precedence[3,3,1,3] = 0.0
# For transportation precedence[3,3,1,4] = 0.0
# For transportation precedence[3,3,1,5] = 0.0
# For transportation precedence[3,3,1,6] = 0.0
# For transportation precedence[3,3,2,1] = 0.0
# For transportation precedence[3,3,2,2] = 0.0
# For transportation precedence[3,3,2,3] = 0.0
# For transportation precedence[3,3,2,4] = 1.0
# For transportation precedence[3,3,2,5] = 1.0
# For transportation precedence[3,3,2,6] = 0.0
# For transportation precedence[3,3,3,1] = 1.0
# For transportation precedence[3,3,3,2] = 0.0
# For transportation precedence[3,3,3,3] = 0.0
# For transportation precedence[3,3,3,4] = 0.0
# For transportation precedence[3,3,3,5] = 0.0
# For transportation precedence[3,3,3,6] = 1.0
# For transportation precedence[3,3,4,1] = 1.0
# For transportation precedence[3,3,4,2] = 0.0
# For transportation precedence[3,3,4,3] = 0.0
# For transportation precedence[3,3,4,4] = 1.0
# For transportation precedence[3,3,4,5] = 1.0
# For transportation precedence[3,3,4,6] = 1.0
# For transportation precedence[3,4,1,1] = 0.0
# For transportation precedence[3,4,1,2] = 0.0
# For transportation precedence[3,4,1,3] = 0.0
# For transportation precedence[3,4,1,4] = 1.0
# For transportation precedence[3,4,1,5] = 1.0
# For transportation precedence[3,4,1,6] = 1.0
# For transportation precedence[3,4,2,1] = 0.0
# For transportation precedence[3,4,2,2] = 0.0
# For transportation precedence[3,4,2,3] = 0.0
# For transportation precedence[3,4,2,4] = 0.0
# For transportation precedence[3,4,2,5] = 0.0
# For transportation precedence[3,4,2,6] = 1.0
# For transportation precedence[3,4,3,1] = 0.0
# For transportation precedence[3,4,3,2] = 0.0
# For transportation precedence[3,4,3,3] = 0.0
# For transportation precedence[3,4,3,4] = 0.0
# For transportation precedence[3,4,3,5] = 1.0
# For transportation precedence[3,4,3,6] = 0.0
# For transportation precedence[3,4,4,1] = 0.0
# For transportation precedence[3,4,4,2] = 0.0
# For transportation precedence[3,4,4,3] = 0.0
# For transportation precedence[3,4,4,4] = 0.0
# For transportation precedence[3,4,4,5] = 0.0
# For transportation precedence[3,4,4,6] = 0.0
# For transportation precedence[3,5,1,1] = 0.0
# For transportation precedence[3,5,1,2] = 0.0
# For transportation precedence[3,5,1,3] = 0.0
# For transportation precedence[3,5,1,4] = 0.0
# For transportation precedence[3,5,1,5] = 1.0
# For transportation precedence[3,5,1,6] = 1.0
# For transportation precedence[3,5,2,1] = 0.0
# For transportation precedence[3,5,2,2] = 0.0
# For transportation precedence[3,5,2,3] = 0.0
# For transportation precedence[3,5,2,4] = 0.0
# For transportation precedence[3,5,2,5] = 0.0
# For transportation precedence[3,5,2,6] = 1.0
# For transportation precedence[3,5,3,1] = 0.0
# For transportation precedence[3,5,3,2] = 0.0
# For transportation precedence[3,5,3,3] = 0.0
# For transportation precedence[3,5,3,4] = 0.0
# For transportation precedence[3,5,3,5] = 0.0
# For transportation precedence[3,5,3,6] = 0.0
# For transportation precedence[3,5,4,1] = 0.0
# For transportation precedence[3,5,4,2] = 0.0
# For transportation precedence[3,5,4,3] = 0.0
# For transportation precedence[3,5,4,4] = 0.0
# For transportation precedence[3,5,4,5] = 0.0
# For transportation precedence[3,5,4,6] = 0.0
# For transportation precedence[3,6,1,1] = 0.0
# For transportation precedence[3,6,1,2] = 0.0
# For transportation precedence[3,6,1,3] = 0.0
# For transportation precedence[3,6,1,4] = 0.0
# For transportation precedence[3,6,1,5] = 0.0
# For transportation precedence[3,6,1,6] = 0.0
# For transportation precedence[3,6,2,1] = 0.0
# For transportation precedence[3,6,2,2] = 0.0
# For transportation precedence[3,6,2,3] = 0.0
# For transportation precedence[3,6,2,4] = 0.0
# For transportation precedence[3,6,2,5] = 0.0
# For transportation precedence[3,6,2,6] = 0.0
# For transportation precedence[3,6,3,1] = 0.0
# For transportation precedence[3,6,3,2] = 0.0
# For transportation precedence[3,6,3,3] = 0.0
# For transportation precedence[3,6,3,4] = 0.0
# For transportation precedence[3,6,3,5] = 0.0
# For transportation precedence[3,6,3,6] = 0.0
# For transportation precedence[3,6,4,1] = 0.0
# For transportation precedence[3,6,4,2] = 0.0
# For transportation precedence[3,6,4,3] = 0.0
# For transportation precedence[3,6,4,4] = 0.0
# For transportation precedence[3,6,4,5] = 0.0
# For transportation precedence[3,6,4,6] = 0.0
# For transportation precedence[4,1,1,1] = 0.0
# For transportation precedence[4,1,1,2] = 0.0
# For transportation precedence[4,1,1,3] = 0.0
# For transportation precedence[4,1,1,4] = 0.0
# For transportation precedence[4,1,1,5] = 0.0
# For transportation precedence[4,1,1,6] = 0.0
# For transportation precedence[4,1,2,1] = 0.0
# For transportation precedence[4,1,2,2] = 0.0
# For transportation precedence[4,1,2,3] = 0.0
# For transportation precedence[4,1,2,4] = 0.0
# For transportation precedence[4,1,2,5] = 1.0
# For transportation precedence[4,1,2,6] = 0.0
# For transportation precedence[4,1,3,1] = 1.0
# For transportation precedence[4,1,3,2] = 0.0
# For transportation precedence[4,1,3,3] = 0.0
# For transportation precedence[4,1,3,4] = 0.0
# For transportation precedence[4,1,3,5] = 0.0
# For transportation precedence[4,1,3,6] = 1.0
# For transportation precedence[4,1,4,1] = 0.0
# For transportation precedence[4,1,4,2] = 0.0
# For transportation precedence[4,1,4,3] = 1.0
# For transportation precedence[4,1,4,4] = 0.0
# For transportation precedence[4,1,4,5] = 1.0
# For transportation precedence[4,1,4,6] = 1.0
# For transportation precedence[4,2,1,1] = 0.0
# For transportation precedence[4,2,1,2] = 0.0
# For transportation precedence[4,2,1,3] = 0.0
# For transportation precedence[4,2,1,4] = 0.0
# For transportation precedence[4,2,1,5] = 0.0
# For transportation precedence[4,2,1,6] = 0.0
# For transportation precedence[4,2,2,1] = 0.0
# For transportation precedence[4,2,2,2] = 0.0
# For transportation precedence[4,2,2,3] = 0.0
# For transportation precedence[4,2,2,4] = 1.0
# For transportation precedence[4,2,2,5] = 1.0
# For transportation precedence[4,2,2,6] = 0.0
# For transportation precedence[4,2,3,1] = 1.0
# For transportation precedence[4,2,3,2] = 0.0
# For transportation precedence[4,2,3,3] = 1.0
# For transportation precedence[4,2,3,4] = 0.0
# For transportation precedence[4,2,3,5] = 0.0
# For transportation precedence[4,2,3,6] = 1.0
# For transportation precedence[4,2,4,1] = 1.0
# For transportation precedence[4,2,4,2] = 0.0
# For transportation precedence[4,2,4,3] = 1.0
# For transportation precedence[4,2,4,4] = 1.0
# For transportation precedence[4,2,4,5] = 1.0
# For transportation precedence[4,2,4,6] = 1.0
# For transportation precedence[4,3,1,1] = 0.0
# For transportation precedence[4,3,1,2] = 0.0
# For transportation precedence[4,3,1,3] = 0.0
# For transportation precedence[4,3,1,4] = 0.0
# For transportation precedence[4,3,1,5] = 0.0
# For transportation precedence[4,3,1,6] = 0.0
# For transportation precedence[4,3,2,1] = 0.0
# For transportation precedence[4,3,2,2] = 0.0
# For transportation precedence[4,3,2,3] = 0.0
# For transportation precedence[4,3,2,4] = 1.0
# For transportation precedence[4,3,2,5] = 1.0
# For transportation precedence[4,3,2,6] = 0.0
# For transportation precedence[4,3,3,1] = 0.0
# For transportation precedence[4,3,3,2] = 0.0
# For transportation precedence[4,3,3,3] = 1.0
# For transportation precedence[4,3,3,4] = 0.0
# For transportation precedence[4,3,3,5] = 0.0
# For transportation precedence[4,3,3,6] = 1.0
# For transportation precedence[4,3,4,1] = 0.0
# For transportation precedence[4,3,4,2] = 0.0
# For transportation precedence[4,3,4,3] = 0.0
# For transportation precedence[4,3,4,4] = 1.0
# For transportation precedence[4,3,4,5] = 1.0
# For transportation precedence[4,3,4,6] = 1.0
# ...
# transportation by agv for job i and operation j binary variable[3,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[1,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,1,2] = 1.0
# transportation by agv for job i and operation j binary variable[1,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,2,2] = 1.0
# transportation by agv for job i and operation j binary variable[1,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,3,2] = 1.0
# transportation by agv for job i and operation j binary variable[1,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,4,2] = 1.0
# transportation by agv for job i and operation j binary variable[1,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,5,2] = 1.0
# transportation by agv for job i and operation j binary variable[1,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[1,6,2] = 1.0
# transportation by agv for job i and operation j binary variable[2,1,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,1,2] = 1.0
# transportation by agv for job i and operation j binary variable[2,2,1] = 1.0
# transportation by agv for job i and operation j binary variable[2,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,3,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,3,2] = 1.0
# transportation by agv for job i and operation j binary variable[2,4,1] = 1.0
# transportation by agv for job i and operation j binary variable[2,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,5,1] = 1.0
# transportation by agv for job i and operation j binary variable[2,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[2,6,1] = 0.0
# transportation by agv for job i and operation j binary variable[2,6,2] = 1.0
# transportation by agv for job i and operation j binary variable[3,1,1] = 1.0
# transportation by agv for job i and operation j binary variable[3,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,2,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,2,2] = 1.0
# transportation by agv for job i and operation j binary variable[3,3,1] = 1.0
# transportation by agv for job i and operation j binary variable[3,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[3,4,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,4,2] = 1.0
# transportation by agv for job i and operation j binary variable[3,5,1] = 0.0
# transportation by agv for job i and operation j binary variable[3,5,2] = 1.0
# transportation by agv for job i and operation j binary variable[3,6,1] = 1.0
# transportation by agv for job i and operation j binary variable[3,6,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,1,1] = 1.0
# transportation by agv for job i and operation j binary variable[4,1,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,2,1] = 1.0
# transportation by agv for job i and operation j binary variable[4,2,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,3,1] = 1.0
# transportation by agv for job i and operation j binary variable[4,3,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,4,1] = 1.0
# transportation by agv for job i and operation j binary variable[4,4,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,5,1] = 1.0
# transportation by agv for job i and operation j binary variable[4,5,2] = 0.0
# transportation by agv for job i and operation j binary variable[4,6,1] = 1.0
# transportation by agv for job i and operation j binary variable[4,6,2] = 0.0
